# %% [markdown]
# # Introduction
# This notebook is the starting point of our Foundation 2 project for ISB AMPBA Term 5. Here we performed dataset cleaning where we removed the columns which were not required as part of the problem statement.
#
# The original dataset was downloaded from [here](https://www.kaggle.com/himanshupoddar/zomato-bangalore-restaurants) and was saved in local drive. You can perform the same by changing the path below to point to your downloaded version. The dataset is not included in repo for its large size

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
import numpy as np
import re

# %%
zomato_data_path = '../datasets/Zomato Bangalore Restaurants Data/zomato_original.csv'
df = pd.read_csv(zomato_data_path)

# %%
df.sample(n=10)
# Out:
#                                                      url  \
# 23370  https://www.zomato.com/bangalore/vinaya-cafe-j...
# 50670  https://www.zomato.com/bangalore/sai-charan-ti...
# 9243   https://www.zomato.com/bangalore/kolkata-famou...
# 23308  https://www.zomato.com/bangalore/cheesiano-piz...
# 27333  https://www.zomato.com/bangalore/eatery-have-u...
# 16689  https://www.zomato.com/bangalore/wings-mama-hs...
# 18225  https://www.zomato.com/bangalore/kings-cafe-an...
# 19802  https://www.zomato.com/bangalore/smoke-de-burg...
# 28422  https://www.zomato.com/bangalore/the-old-fashi...
# 50182  https://www.zomato.com/bangalore/cakezone-vart...
#
#                                                  address  \
# 23370  30, 33rd Main, 16th Cross, 6th Phase, JP Nagar...
# 50670  32/4, Near D Mart,Varthur Main Road, Whitefiel...
# 9243   8, 24th Main, Opposite Royal School, Phase 5, ...
# 23308  16, 17, 18/2 Sarakki Lake, 24th Main, 6th Phas...
# 27333  767-768, 16th Main Road, MCHS Colony, Stage 2,...
# 16689  1086/A, Twin Tulips, Near BDA Complex, 18th Cr...
# 18225  18, 17 F Cross, 2nd Stage, Indiranagar, Bangalore
# 19802          Shop 50, Koramangala 5th Block, Bangalore
# 28422  470, 80 Feet Road, Koramangala 6th Block, Bang...
# 50182  710, Thubarahalli, Varthur Main Road, Whitefie...
#
#                            name online_order book_table    rate  votes  \
# 23370               Vinaya Cafe          Yes         No   3.7/5     55
# 50670   Sai Charan Tiffin House           No         No     NaN      0
# 9243   Kolkata Famous Kati Roll          Yes         No   3.5/5     11
# 23308           Cheesiano Pizza          Yes        Yes   4.0/5    205
# 27333        Eatery Have U Been          Yes         No   3.4/5     35
# 16689                Wings Mama          Yes         No     NaN      0
# 18225    King's Cafe And Restro           No         No     NaN      0
# 19802           Smoke de Burger          Yes         No   3.6/5     36
# 28422     The Old Fashioned Bar           No        Yes  4.5 /5    569
# 50182                  CakeZone          Yes         No  3.9 /5     33
#
#                                   phone                       location  \
# 23370    080 41233313\r\n+91 7022281100                       JP Nagar
# 50670                    +91 9535154001                     Whitefield
# 9243   +91 9620076440\r\n+91 7892737394                       JP Nagar
# 23308  +91 8043761455\r\n+91 7678077768                       JP Nagar
# 27333                    +91 9743524748                            BTM
# 16689                    +91 8095066833                            HSR
# 18225  +91 9916533331\r\n+91 9916533332                    Indiranagar
# 19802                    +91 9591066373          Koramangala 5th Block
# 28422                      080 49652711          Koramangala 6th Block
# 50182                      080 43334321  Varthur Main Road, Whitefield
#
#                 rest_type                                         dish_liked  \
# 23370         Quick Bites                                Coffee, Masala Dosa
# 50670         Quick Bites                                                NaN
# 9243          Quick Bites                                                NaN
# 23308         Quick Bites  Pasta, Fries, Cheesiano Pizza, Veggie Pizza, C...
# 27333   Cafe, Quick Bites                                                NaN
# 16689  Takeaway, Delivery                                                NaN
# 18225            Delivery                                                NaN
# 19802         Quick Bites                                                NaN
# 28422                 Bar  Cocktails, Long Island Iced Tea, Draught Beer,...
# 50182  Takeaway, Delivery                                                NaN
#
#                                              cuisines  \
# 23370               South Indian, Street Food, Juices
# 50670                                    South Indian
# 9243                                   Rolls, Chinese
# 23308                                  Pizza, Italian
# 27333  Cafe, Chinese, Fast Food, Burger, North Indian
# 16689                             American, Fast Food
# 18225                           North Indian, Biryani
# 19802                                       Fast Food
# 28422          Finger Food, North Indian, Continental
# 50182                                Bakery, Desserts
#
#       approx_cost(for two people)  \
# 23370                         200
# 50670                         150
# 9243                          200
# 23308                         700
# 27333                         500
# 16689                         300
# 18225                         550
# 19802                         300
# 28422                       1,000
# 50182                         200
#
#                                             reviews_list  \
# 23370  [('Rated 5.0', 'RATED\n  Very kind staff and o...
# 50670  [('Rated 5.0', 'RATED\n  Hi this restaurant st...
# 9243   [('Rated 4.0', "RATED\n  They make delicious r...
# 23308  [('Rated 5.0', "RATED\n  The pizza's were amaz...
# 27333  [('Rated 5.0', 'RATED\n  Good ambience. Very g...
# 16689                                                 []
# 18225                                                 []
# 19802  [('Rated 4.0', "RATED\n  Visited this place on...
# 28422  [('Rated 5.0', 'RATED\n  Never been to a bette...
# 50182  [('Rated 5.0', "RATED\n  They have very nice v...
#
#                                                menu_item listed_in(type)  \
# 23370  ['Plain Dosa', 'Masala Dosa', 'Idli Vada', 'Pa...        Dine-out
# 50670                                                 []        Delivery
# 9243                                                  []        Delivery
# 23308  ['French Fries', 'Cheese Garlic Bread', 'Chees...        Dine-out
# 27333                                                 []        Delivery
# 16689                                                 []        Delivery
# 18225                                                 []        Delivery
# 19802  ['Veg White Sauce Pasta', 'Chicken White Sauce...        Delivery
# 28422                                                 []        Dine-out
# 50182  ['Chocolate Truffle Cake (500 Grams)', 'Black ...        Delivery
#
#              listed_in(city)
# 23370               JP Nagar
# 50670             Whitefield
# 9243                     BTM
# 23308               JP Nagar
# 27333  Koramangala 4th Block
# 16689                    HSR
# 18225            Indiranagar
# 19802              Jayanagar
# 28422  Koramangala 4th Block
# 50182             Whitefield

# %% [markdown]
# # Check distinct values of output variable

# %%
df.rate.value_counts().to_dict()
# Out:
# {'NEW': 2208,
#  '3.9/5': 2098,
#  '3.8/5': 2022,
#  '3.7/5': 2011,
#  '3.9 /5': 1874,
#  '3.8 /5': 1851,
#  '3.7 /5': 1810,
#  '3.6/5': 1773,
#  '4.0/5': 1609,
#  '4.0 /5': 1574,
#  '3.6 /5': 1543,
#  '4.1 /5': 1474,
#  '4.1/5': 1474,
#  '3.5/5': 1431,
#  '3.5 /5': 1353,
#  '3.4/5': 1259,
#  '3.4 /5': 1217,
#  '3.3/5': 1168,
#  '4.2 /5': 1165,
#  '3.3 /5': 1142,
#  '4.2/5': 1019,
#  '3.2/5': 1006,
#  '4.3 /5': 917,
#  '3.2 /5': 867,
#  '3.1/5': 862,
#  '4.3/5': 776,
#  '3.1 /5': 699,
#  '4.4 /5': 628,
#  '3.0/5': 558,
#  '4.4/5': 519,
#  '3.0 /5': 465,
#  '2.9/5': 427,
#  '4.5 /5': 409,
#  '2.9 /5': 375,
#  '2.8/5': 313,
#  '2.8 /5': 287,
#  '4.5/5': 247,
#  '4.6 /5': 175,
#  '2.7/5': 170,
#  '2.6/5': 143,
#  '2.7 /5': 137,
#  '4.6/5': 125,
#  '2.6 /5': 117,
#  '4.7 /5': 86,
#  '4.7/5': 81,
#  '-': 69,
#  '2.5 /5': 56,
#  '2.5/5': 45,
#  '4.8 /5': 43,
#  '2.4/5': 40,
#  '4.9 /5': 30,
#  '2.4 /5': 30,
#  '2.3/5': 28,
#  '4.9/5': 25,
#  '2.3 /5': 23,
#  '4.8/5': 23,
#  '2.2/5': 19,
#  '2.1 /5': 13,
#  '2.1/5': 11,
#  '2.2 /5': 7,
#  '2.0 /5': 7,
#  '2.0/5': 4,
#  '1.8 /5': 3,
#  '1.8/5': 2}

# %% [markdown]
# **Observation:** There are many ratings with uncleaned texts we have to manage them

# %% [markdown]
# # Feature selection by problem statement
# As per our problem statement we will make the feature selection as below for modelling purpose:
#
# | Feature | Comments |
# | :- | :- |
# | url | Not used URL has nothing to do with ratings |
# | address | Raw address is not required as we will focus on location information |
# | name | Name has nothing to do with rating |
# | online_order | **Required**. We need to model with online_order. Online delivery service plays good role |
# | book_table | **Required**. Table booking feature can play good role in ratings |
# | rate | **Required**.  Target variable |
# | votes | Not selected as new restaurants which will be onboarded will have little or no votes. Cold start problem |
# | phone | Not required|
# | location | May be required. We are also capturing the info in **listed_in(city)** |
# | rest_type | **Required**. Restaurant type might have some effect |
# | dish_liked | Not required. New onboarded restaurant will not have this info. |
# | cuisines | **Required**. |
# | approx_cost(for two people) | **Required**. |
# | reviews_list | Not required as of now. Cold start problem. |
# | menu_item | **Required**. Requires data cleaning |
# | listed_in(type) | **Required**. |
# | listed_in(city) | **Required**.  |

# %% [markdown]
# ## Dropping the reviews list as its large and we don't need them anyway for our application

# %%
df = df.drop(columns=['reviews_list'])
df.sample(10)
# Out:
#                                                      url  \
# 14159  https://www.zomato.com/bangalore/amaravati-1-e...
# 43885  https://www.zomato.com/bangalore/the-hub-ibis-...
# 15031  https://www.zomato.com/bangalore/aqni-rt-nagar...
# 16717  https://www.zomato.com/bangalore/masale-daan-h...
# 26489  https://www.zomato.com/bangalore/onesta-korama...
# 17580  https://www.zomato.com/bangalore/the-ants-cafe...
# 9392   https://www.zomato.com/bangalore/dr-shawarma-h...
# 6999   https://www.zomato.com/bangalore/basaveshwara-...
# 126    https://www.zomato.com/bangalore/banashankari-...
# 42540  https://www.zomato.com/bangalore/taipan-1-fraz...
#
#                                                  address  \
# 14159  9, Near Infosys Gate 3, Electronic City, Banga...
# 43885  Ibis Hotel, Bengaluru City Centre, Plot 30, Ra...
# 15031  1, 15th Cross, 2nd Block, Next to Patel's Inn,...
# 16717  14th Main Road Sector 4, HSR Layout, HSR, Bang...
# 26489    562, 8th Main, Koramangala 4th Block, Bangalore
# 17580  2286/B, 1st Cross, 14th A Main, HAL 2nd Stage,...
# 9392   Shop 1087/A, 14th Main, 18th Cross, 3rd Sector...
# 6999   Nanjudeshwari complex, Oppsite Brookefield Mal...
# 126    17/1, Ramalh Garden, Kadieranahall Circle, Nea...
# 42540  57, Coles Road, Near ICICI Bank, Frazer Town, ...
#
#                           name online_order book_table    rate  votes  \
# 14159                Amaravati           No         No     NaN      0
# 43885     The Hub - Ibis Hotel           No         No  3.5 /5     29
# 15031                     AQNI          Yes         No   3.0/5      9
# 16717              Masale Daan          Yes         No     NaN      0
# 26489                   Onesta          Yes        Yes   4.4/5   9064
# 17580    The Ants Cafe & Store          Yes        Yes   3.9/5   1380
# 9392              Dr. Shawarma          Yes         No     NaN      0
# 6999    Basaveshwara Khanavali           No         No     NaN      0
# 126    Banashankari Nati Style           No         No     NaN      0
# 42540                   Taipan          Yes         No  3.5 /5    129
#
#                                   phone               location  \
# 14159    +91 9663059999\r\n080 41217666        Electronic City
# 43885      080 42548005\n+91 7022032592          Richmond Road
# 15031  +91 8095929928\r\n+91 9900918842               RT Nagar
# 16717                    +91 8043334333                    HSR
# 26489      080 43723443\r\n080 43705665  Koramangala 4th Block
# 17580    +91 7204701157\r\n080 41715639            Indiranagar
# 9392                     +91 9632680729                    HSR
# 6999   +91 9740912864\r\n+91 7353747430            Brookefield
# 126    +91 9035141678\r\n+91 9742174293           Banashankari
# 42540      +91 8041251279\n080 25467784            Frazer Town
#
#                  rest_type                                         dish_liked  \
# 14159        Casual Dining                                                NaN
# 43885                  Bar                                                NaN
# 15031          Quick Bites                                                NaN
# 16717   Takeaway, Delivery                                                NaN
# 26489  Casual Dining, Cafe  Berryblast, Gourmet Pizza, Mocktails, Ravioli,...
# 17580                 Cafe  English Breakfast, Coffee, Watermelon Feta Sal...
# 9392           Quick Bites                                                NaN
# 6999           Quick Bites                                                NaN
# 126            Quick Bites                                                NaN
# 42540        Casual Dining                 Noodles, Dragon Chicken, Chop Suey
#
#                                            cuisines  \
# 14159        Andhra, North Indian, Chinese, Seafood
# 43885           Finger Food, Fast Food, Continental
# 15031                         North Indian, Mughlai
# 16717                                  North Indian
# 26489                          Pizza, Cafe, Italian
# 17580                                 Cafe, Italian
# 9392               North Indian, Rolls, Street Food
# 6999                                   South Indian
# 126    Biryani, Chinese, South Indian, North Indian
# 42540                                Chinese, Momos
#
#       approx_cost(for two people)  \
# 14159                         600
# 43885                       2,200
# 15031                         500
# 16717                         350
# 26489                         600
# 17580                         900
# 9392                          200
# 6999                          200
# 126                           350
# 42540                         700
#
#                                                menu_item     listed_in(type)  \
# 14159                                                 []            Dine-out
# 43885                                                 []  Drinks & nightlife
# 15031  ['Chicken Biryani', 'Memon Mutton Biryani', 'K...            Delivery
# 16717                                                 []            Delivery
# 26489  ['Nutella Chocolate Mousse', 'French Fries', '...              Buffet
# 17580                                                 []               Cafes
# 9392                                                  []            Delivery
# 6999                                                  []            Delivery
# 126                                                   []            Delivery
# 42540                                                 []            Delivery
#
#              listed_in(city)
# 14159        Electronic City
# 43885                MG Road
# 15031            Frazer Town
# 16717                    HSR
# 26489  Koramangala 4th Block
# 17580            Indiranagar
# 9392                     BTM
# 6999             Brookefield
# 126             Banashankari
# 42540                MG Road

# %% [markdown]
# # Column Renames

# %%
rename_dict = {'approx_cost(for two people)':'cost'
               ,'listed_in(type)':'listed_in_type'
               ,'listed_in(city)':'listed_in_city'
              }
df = df.rename(columns=rename_dict)
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines cost menu_item listed_in_type listed_in_city
# 0  North Indian, Mughlai, Chinese  800        []         Buffet   Banashankari
# 1     Chinese, North Indian, Thai  800        []         Buffet   Banashankari
# 2          Cafe, Mexican, Italian  800        []         Buffet   Banashankari
# 3      South Indian, North Indian  300        []         Buffet   Banashankari
# 4        North Indian, Rajasthani  600        []         Buffet   Banashankari

# %% [markdown]
# **Observation:**
# 1. cuisines, menu_item, rest_type require count vectorization using ', ' separated values
# 1. online_order, book_table, listed_in_city, listed_in_type require one hot encoding

# %% [markdown]
# # Simple EDA

# %% [markdown]
# ## Categorical columns

# %%
categorical_cols = ['online_order',
                    'book_table',
                    'location',
                    'rest_type',
                    'listed_in_type',
                    'listed_in_city'
                   ]
for col in categorical_cols:
    print('****{}****'.format(col))
    print(df[col].value_counts().to_dict())
    print('-'*5,'NaNs present','-'*5)
    print(df[col].isna().sum())
# Out:
# ****online_order****
# {'Yes': 30444, 'No': 21273}
# ----- NaNs present -----
# 0
# ****book_table****
# {'No': 45268, 'Yes': 6449}
# ----- NaNs present -----
# 0
# ****location****
# {'BTM': 5124, 'HSR': 2523, 'Koramangala 5th Block': 2504, 'JP Nagar': 2235, 'Whitefield': 2144, 'Indiranagar': 2083, 'Jayanagar': 1926, 'Marathahalli': 1846, 'Bannerghatta Road': 1630, 'Bellandur': 1286, 'Electronic City': 1258, 'Koramangala 1st Block': 1238, 'Brigade Road': 1218, 'Koramangala 7th Block': 1181, 'Koramangala 6th Block': 1156, 'Sarjapur Road': 1065, 'Ulsoor': 1023, 'Koramangala 4th Block': 1017, 'MG Road': 918, 'Banashankari': 906, 'Kalyan Nagar': 853, 'Richmond Road': 812, 'Frazer Town': 727, 'Malleshwaram': 725, 'Basavanagudi': 684, 'Residency Road': 675, 'Banaswadi': 664, 'Brookefield': 658, 'New BEL Road': 649, 'Kammanahalli': 648, 'Rajajinagar': 591, 'Church Street': 569, 'Lavelle Road': 529, 'Shanti Nagar': 511, 'Shivajinagar': 499, 'Domlur': 496, 'Cunningham Road': 491, 'Old Airport Road': 446, 'Ejipura': 439, 'Commercial Street': 370, 'St. Marks Road': 352, 'Koramangala 8th Block': 320, 'Vasanth Nagar': 295, 'Jeevan Bhima Nagar': 272, 'Wilson Garden': 246, 'Bommanahalli': 238, 'Koramangala 3rd Block': 216, 'Kumaraswamy Layout': 195, 'Thippasandra': 194, 'Basaveshwara Nagar': 191, 'Nagawara': 187, 'Seshadripuram': 165, 'Hennur': 161, 'Majestic': 155, 'HBR Layout': 153, 'Infantry Road': 151, 'Race Course Road': 139, 'City Market': 126, 'Yeshwantpur': 119, 'Varthur Main Road, Whitefield': 117, 'ITPL Main Road, Whitefield': 113, 'South Bangalore': 107, 'Koramangala 2nd Block': 102, 'Hosur Road': 102, 'Kaggadasapura': 101, 'CV Raman Nagar': 90, 'Vijay Nagar': 80, 'RT Nagar': 80, 'Sanjay Nagar': 76, 'Sadashiv Nagar': 63, 'Sahakara Nagar': 53, 'Koramangala': 48, 'East Bangalore': 44, 'Jalahalli': 38, 'Magadi Road': 34, 'Rammurthy Nagar': 32, 'Langford Town': 27, 'Sankey Road': 27, 'Old Madras Road': 22, 'Mysore Road': 22, 'Kanakapura Road': 19, 'KR Puram': 18, 'Uttarahalli': 17, 'Hebbal': 14, 'North Bangalore': 14, 'Kengeri': 9, 'Nagarbhavi': 9, 'Central Bangalore': 8, 'West Bangalore': 6, 'Yelahanka': 6, 'Jakkur': 3, 'Rajarajeshwari Nagar': 2, 'Peenya': 1}
# ----- NaNs present -----
# 21
# ****rest_type****
# {'Quick Bites': 19132, 'Casual Dining': 10330, 'Cafe': 3732, 'Delivery': 2604, 'Dessert Parlor': 2263, 'Takeaway, Delivery': 2037, 'Casual Dining, Bar': 1154, 'Bakery': 1141, 'Beverage Shop': 867, 'Bar': 697, 'Food Court': 624, 'Sweet Shop': 468, 'Bar, Casual Dining': 425, 'Lounge': 396, 'Pub': 357, 'Fine Dining': 346, 'Casual Dining, Cafe': 319, 'Beverage Shop, Quick Bites': 298, 'Bakery, Quick Bites': 289, 'Mess': 267, 'Pub, Casual Dining': 255, 'Sweet Shop, Quick Bites': 178, 'Kiosk': 176, 'Dessert Parlor, Cafe': 175, 'Cafe, Casual Dining': 173, 'Cafe, Bakery': 164, 'Cafe, Dessert Parlor': 148, 'Bakery, Dessert Parlor': 147, 'Microbrewery, Casual Dining': 132, 'Casual Dining, Pub': 127, 'Dessert Parlor, Quick Bites': 125, 'Takeaway': 120, 'Cafe, Quick Bites': 111, 'Food Court, Quick Bites': 101, 'Quick Bites, Beverage Shop': 101, 'Dessert Parlor, Bakery': 85, 'Quick Bites, Dessert Parlor': 84, 'Food Truck': 84, 'Pub, Microbrewery': 84, 'Dessert Parlor, Beverage Shop': 80, 'Beverage Shop, Dessert Parlor': 79, 'Bakery, Cafe': 78, 'Quick Bites, Sweet Shop': 75, 'Quick Bites, Bakery': 60, 'Casual Dining, Microbrewery': 59, 'Confectionery': 47, 'Microbrewery, Pub': 42, 'Quick Bites, Cafe': 41, 'Pub, Cafe': 40, 'Pub, Bar': 40, 'Fine Dining, Bar': 40, 'Dhaba': 40, 'Club': 37, 'Lounge, Casual Dining': 37, 'Lounge, Bar': 36, 'Microbrewery': 30, 'Beverage Shop, Cafe': 28, 'Quick Bites, Food Court': 19, 'Cafe, Bar': 19, 'Bakery, Beverage Shop': 16, 'Lounge, Cafe': 16, 'Lounge, Microbrewery': 16, 'Cafe, Lounge': 15, 'Casual Dining, Irani Cafee': 15, 'Fine Dining, Lounge': 14, 'Bar, Cafe': 13, 'Bakery, Kiosk': 13, 'Microbrewery, Bar': 13, 'Dessert Parlor, Sweet Shop': 12, 'Casual Dining, Lounge': 10, 'Bar, Quick Bites': 9, 'Microbrewery, Lounge': 9, 'Food Court, Dessert Parlor': 8, 'Casual Dining, Sweet Shop': 8, 'Bar, Lounge': 6, 'Fine Dining, Microbrewery': 5, 'Food Court, Casual Dining': 5, 'Bar, Pub': 5, 'Casual Dining, Quick Bites': 4, 'Club, Casual Dining': 4, 'Quick Bites, Mess': 4, 'Quick Bites, Meat Shop': 4, 'Bakery, Sweet Shop': 3, 'Bhojanalya': 3, 'Mess, Quick Bites': 3, 'Pop Up': 2, 'Bakery, Food Court': 2, 'Cafe, Food Court': 2, 'Dessert Parlor, Kiosk': 2, 'Food Court, Beverage Shop': 2, 'Dessert Parlor, Food Court': 2, 'Sweet Shop, Dessert Parlor': 1, 'Quick Bites, Kiosk': 1}
# ----- NaNs present -----
# 227
# ****listed_in_type****
# {'Delivery': 25942, 'Dine-out': 17779, 'Desserts': 3593, 'Cafes': 1723, 'Drinks & nightlife': 1101, 'Buffet': 882, 'Pubs and bars': 697}
# ----- NaNs present -----
# 0
# ****listed_in_city****
# {'BTM': 3279, 'Koramangala 7th Block': 2938, 'Koramangala 5th Block': 2836, 'Koramangala 4th Block': 2779, 'Koramangala 6th Block': 2623, 'Jayanagar': 2371, 'JP Nagar': 2096, 'Indiranagar': 1860, 'Church Street': 1827, 'MG Road': 1811, 'Brigade Road': 1769, 'Lavelle Road': 1744, 'HSR': 1741, 'Marathahalli': 1659, 'Residency Road': 1620, 'Whitefield': 1620, 'Bannerghatta Road': 1617, 'Brookefield': 1518, 'Old Airport Road': 1425, 'Kammanahalli': 1329, 'Kalyan Nagar': 1309, 'Basavanagudi': 1266, 'Sarjapur Road': 1261, 'Electronic City': 1229, 'Bellandur': 1227, 'Frazer Town': 1185, 'Malleshwaram': 1096, 'Rajajinagar': 1079, 'Banashankari': 863, 'New BEL Road': 740}
# ----- NaNs present -----
# 0

# %% [markdown]
# **Observation:**
# 1. We can substitute some locations which have very less counts as "Others"
# 1. rest_type is not a one-to-one mapping. It needs to be handled through count Vectorizer.
# 1. There can be direct correlation of **listed_in(city)** and **location**. As per our understanding **listed_in(city)** seems to be more drill down of **location**. So for overall view, we can go with **listed_in(city)**. Need to confirm with B'lore people on these. However there are presence of NaNs in the **location** field. So we will use **listed_in(city)** for it has complete information.
# 1. Fields like **rest_type** contains too many categories which are comma-separated. We need to perform encoding by count vectorization

# %% [markdown]
# ## Preprocess the columns
# Since rating column is given in the form of string we need to preprocess it to float

# %%
def preprocess_rating(rating):
    try:
        rate = float(rating.split('/')[0].strip())
    except:
        rate = None
    return rate
def preprocess_cost(cost):
    try:
        cost_cleaned = float(re.sub('\,','',cost))
    except:
        cost_cleaned = None
    return cost_cleaned
def preprocess_menu_item(menu_item:list):
    try:
        menu = ', '.join(eval(menu_item))
    except:
        menu = None
    return menu
df['rate'] = df.rate.apply(lambda element: preprocess_rating(element))
df['cost'] = df['cost'].apply(lambda element: preprocess_cost(element))
df['menu_item'] = df['menu_item'].apply(lambda element: preprocess_menu_item(element))

# %% [markdown]
# **Observation:** So our custom column cleaner is working fine we can drop these original columns

# %%
df.sample(10).dtypes
# Out:
# url                object
# address            object
# name               object
# online_order       object
# book_table         object
# rate              float64
# votes               int64
# phone              object
# location           object
# rest_type          object
# dish_liked         object
# cuisines           object
# cost              float64
# menu_item          object
# listed_in_type     object
# listed_in_city     object
# dtype: object

# %% [markdown]
# # Segregate the unrated restaurants

# %%
unrated_rest = df[df.rate.isna()]
df = df[~df.rate.isna()]

# %%
display('Unrated restaurants:::',unrated_rest.sample(10))
display('Rated restaurants:::',df.sample(10))
# Out:
# 'Unrated restaurants:::'
#                                                      url  \
# 11868  https://www.zomato.com/bangalore/momo-time-uls...
# 40856  https://www.zomato.com/bangalore/chawlas-2-onl...
# 20697  https://www.zomato.com/bangalore/ss-hot-dhum-b...
# 48515  https://www.zomato.com/bangalore/sri-sai-sagar...
# 4372   https://www.zomato.com/bangalore/ghar-ka-chulh...
# 22296  https://www.zomato.com/bangalore/nourich-jp-na...
# 51382  https://www.zomato.com/bangalore/dhadoom-white...
# 31771  https://www.zomato.com/bangalore/momo-time-btm...
# 38180  https://www.zomato.com/bangalore/bib-breakfast...
# 43647  https://www.zomato.com/bangalore/shalimar-chas...
#
#                                                  address  \
# 11868  31, Sree Yellamma Temple Street, near BIB, Uls...
# 40856  150, 10th cross, Green Garden Layout, Sai Baba...
# 20697  No 24, 4th Main Balaji Nagar, DRCPost, Krishna...
# 48515  14/15, Manipal Center 47, Dickenson Road, MG R...
# 4372   Number 1204, D block, 7th cross, AECS layout, ...
# 22296  67, Ground Floor, 3rd E Main Road, 15th Cross ...
# 51382  FB 10, 3rd Floor, VR Bangalore, Mahadevapura, ...
# 31771  39, 18th Main, 7th Cross, BTM 1st Stage, Oppos...
# 38180  31, Sree Yellamma Temple Street, Ulsoor, Banga...
# 43647                          Bazar Street, Neelasandra
#
#                             name online_order book_table  rate  votes  \
# 11868                  Momo Time          Yes         No   NaN      0
# 40856      Chawla's 2 online.com           No         No   NaN      0
# 20697  SS Hot Dhum Briyani Point           No         No   NaN      0
# 48515         Sri Sai Sagar Food           No         No   NaN      0
# 4372              Ghar Ka Chulha           No         No   NaN      0
# 22296                    Nourich          Yes        Yes   NaN      0
# 51382                    Dhadoom           No         No   NaN      0
# 31771                  Momo Time          Yes         No   NaN      0
# 38180   BIB-Breakfast In The Box          Yes         No   NaN      0
# 43647            Shalimar Chaska           No         No   NaN      0
#
#                                     phone       location           rest_type  \
# 11868                      +91 9036011861         Ulsoor  Takeaway, Delivery
# 40856      +91 7065123000\n+91 9910009994   Marathahalli            Delivery
# 20697    +91 7892293634\r\n+91 8553137892            BTM         Quick Bites
# 48515                      +91 9845815667        MG Road         Quick Bites
# 4372                       +91 9716775607   Marathahalli            Delivery
# 22296  +91 9945675038\r\r\n+91 8970112299       JP Nagar       Casual Dining
# 51382                      +91 7899255941     Whitefield          Food Court
# 31771                      +91 9036011861            BTM         Quick Bites
# 38180      +91 9886217725\n+91 9538948306         Ulsoor         Quick Bites
# 43647                      +91 9535050784  Richmond Road         Quick Bites
#
#                                               dish_liked  \
# 11868                                                NaN
# 40856                                                NaN
# 20697                                                NaN
# 48515                                                NaN
# 4372                                                 NaN
# 22296  Soba Noodles, Pad Thai Noodle, Pickled Beetroo...
# 51382                                                NaN
# 31771                                                NaN
# 38180                                                NaN
# 43647                                                NaN
#
#                                                 cuisines   cost  \
# 11868                                     Momos, Chinese  300.0
# 40856                              North Indian, Chinese  900.0
# 20697                North Indian, Chinese, South Indian  200.0
# 48515               Street Food, Fast Food, North Indian  300.0
# 4372                                        North Indian  150.0
# 22296  Continental, Chinese, North Indian, Asian, Hea...  800.0
# 51382                Italian, Mexican, Burger, Fast Food  450.0
# 31771                                    Momos, American  600.0
# 38180                              American, Continental  600.0
# 43647                                 Fast Food, Chinese  200.0
#
#                                                menu_item listed_in_type  \
# 11868                                                          Delivery
# 40856                                                          Delivery
# 20697                                                          Delivery
# 48515                                                          Dine-out
# 4372                                                           Delivery
# 22296  Murg Malai Kebab, Goan Fish Curry, Vegetarian ...       Delivery
# 51382                                                          Dine-out
# 31771                                                          Dine-out
# 38180                                                          Delivery
# 43647                                                          Dine-out
#
#               listed_in_city
# 11868          Church Street
# 40856           Marathahalli
# 20697              Jayanagar
# 48515         Residency Road
# 4372               Bellandur
# 22296               JP Nagar
# 51382             Whitefield
# 31771  Koramangala 5th Block
# 38180           Lavelle Road
# 43647                MG Road
# 'Rated restaurants:::'
#                                                      url  \
# 34023  https://www.zomato.com/bangalore/eagles-pizza-...
# 25253  https://www.zomato.com/bangalore/d-zaprino-nag...
# 4448   https://www.zomato.com/bangalore/smokin-bites-...
# 45281  https://www.zomato.com/bangalore/linoui-the-le...
# 43314  https://www.zomato.com/bangalore/the-rice-bowl...
# 19737  https://www.zomato.com/bangalore/the-belgian-w...
# 36825  https://www.zomato.com/bangalore/wtf-koramanga...
# 47622  https://www.zomato.com/bangalore/fat-buddha-cu...
# 5298   https://www.zomato.com/bangalore/ciclo-cafe-in...
# 2497   https://www.zomato.com/bangalore/onesta-basava...
#
#                                                  address  \
# 34023  120, 80 Feet Road, Koramangala 7th Block, Bang...
# 25253  2/1, Next To Maruti Medicals, Jayamma Complex,...
# 4448   First Floor, Shree Complex, Opposite Salarpuri...
# 45281  The Collonnade, The Leela Palace, Old Airport ...
# 43314                      40/2, Lavelle Road, Bangalore
# 19737  Shop 62, The High Street, 11th Main, 4th Block...
# 36825  63, 5th Block, Jyoti Nivas College Road, Koram...
# 47622  70, Near Accenture Building, Cunningham Road, ...
# 5298              12th Main Road, Indiranagar, Bangalore
# 2497   90/66, 1st Floor, Gandhi Bazar Main Road, Basa...
#
#                              name online_order book_table  rate  votes  \
# 34023                Eagles Pizza          Yes         No   3.8     19
# 25253                   D-Zaprino          Yes         No   3.8     25
# 4448                 Smokin Bites          Yes         No   3.4     20
# 45281  L'inoui - The Leela Palace           No         No   3.5      9
# 43314               The Rice Bowl          Yes        Yes   4.3    509
# 19737      The Belgian Waffle Co.          Yes         No   3.8    151
# 36825                         WTF          Yes         No   4.1     96
# 47622                  Fat Buddha          Yes        Yes   4.0    457
# 5298                   Ciclo Cafe          Yes         No   4.3   1283
# 2497                       Onesta          Yes        Yes   4.6   1755
#
#                                     phone               location  \
# 34023                      +91 8296052909  Koramangala 7th Block
# 25253                      +91 9916957618               Nagawara
# 4448                       +91 9538909155          Sarjapur Road
# 45281                        080 41284128       Old Airport Road
# 43314                        080 49653104           Lavelle Road
# 19737                      00 08041010202              Jayanagar
# 36825                        080 43758178  Koramangala 5th Block
# 47622          080 41235139\n080 22343771        Cunningham Road
# 5298   00 08048664512\r\r\n+91 7829278585            Indiranagar
# 2497                       +91 8049525686           Basavanagudi
#
#                  rest_type                                         dish_liked  \
# 34023        Casual Dining                                                NaN
# 25253   Takeaway, Delivery                                                NaN
# 4448           Quick Bites                                                NaN
# 45281       Dessert Parlor                                                NaN
# 43314   Casual Dining, Bar  Rice Bowl, Lamb, Chocolava, Rolls, Paneer Manc...
# 19737       Dessert Parlor                                            Waffles
# 36825                 Cafe  Cheesy Pizza, Cheese Pasta, Brownie Milkshake,...
# 47622        Casual Dining  Crab Soup, Noodles, Wine, Spicy Crabmeat Soup,...
# 5298   Cafe, Casual Dining  Pizza, Cheesy Fries, Tiramisu, Ravioli Pasta, ...
# 2497   Casual Dining, Cafe  Barbeque Chicken Pizza, Mushroom Ravioli, Past...
#
#                        cuisines    cost  \
# 34023            Pizza, Italian   400.0
# 25253  Fast Food, Burger, Pizza   350.0
# 4448      North Indian, Chinese   200.0
# 45281                  Desserts   400.0
# 43314            Chinese, Momos  1300.0
# 19737       Desserts, Beverages   350.0
# 36825         Cafe, Continental   600.0
# 47622             Chinese, Thai  1000.0
# 5298    Cafe, Italian, American  1000.0
# 2497       Pizza, Cafe, Italian   600.0
#
#                                                menu_item listed_in_type  \
# 34023                                                          Dine-out
# 25253  Zap Veggie Burger, Zap Chilli Cheese Melt Burg...       Delivery
# 4448                                                           Delivery
# 45281                                                          Delivery
# 43314                                                          Dine-out
# 19737  Blueberry Cream Cheese Waffle, Butterscotch Cr...       Delivery
# 36825  Margherita Pizza, BBQ Chicken Pizza, Chicken P...       Dine-out
# 47622                                                          Delivery
# 5298   Home Made Fettucini Aglio Olio Pasta, Basil Ri...       Delivery
# 2497                                                              Cafes
#
#               listed_in_city
# 34023  Koramangala 6th Block
# 25253           Kammanahalli
# 4448               Bellandur
# 45281       Old Airport Road
# 43314                MG Road
# 19737              Jayanagar
# 36825  Koramangala 7th Block
# 47622         Residency Road
# 5298            Brigade Road
# 2497            Basavanagudi

# %% [markdown]
# # Save the DF

# %% [markdown]
# ## Save the training dataframe
# Note: If you are saving the DF(s) to GCS use the below command to point to the service account key downloaded in local. Else ignore and save the files to local directory

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'C:\Users\sandipto.sanyal\OneDrive - Accenture\Documents\Study materials\self study\app_deployment\gcloud\sandipto-project-1763acaafc53.json'

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table  rate  votes                             phone  \
# 0          Yes        Yes   4.1    775    080 42297555\r\n+91 9743772233
# 1          Yes         No   4.1    787                      080 41714161
# 2          Yes         No   3.8    918                    +91 9663487993
# 3           No         No   3.7     88                    +91 9620009302
# 4           No         No   3.8    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines   cost menu_item listed_in_type  \
# 0  North Indian, Mughlai, Chinese  800.0                   Buffet
# 1     Chinese, North Indian, Thai  800.0                   Buffet
# 2          Cafe, Mexican, Italian  800.0                   Buffet
# 3      South Indian, North Indian  300.0                   Buffet
# 4        North Indian, Rajasthani  600.0                   Buffet
#
#   listed_in_city
# 0   Banashankari
# 1   Banashankari
# 2   Banashankari
# 3   Banashankari
# 4   Banashankari

# %% [markdown]
# ## Saving the training file.
# This file will be used for model training

# %%
df.to_csv('gs://foundation_project2/training_folder/zomato.csv', index=False)

# %% [markdown]
# ## Prediction files
# Since prediction needs to be fast we will save chunks of our dataframe as per **listed_in_city**

# %% [markdown]
# ### Group restaurants in Koramangala
# Since Koramangala is divided into several blocks we will group them into one

# %%
def get_area(listed_in_city:str):
    if 'Koramangala' in listed_in_city:
        return 'Koramangala'
    else:
        return listed_in_city
unrated_rest['area'] = unrated_rest.listed_in_city.apply(get_area)
unrated_rest.area.value_counts().to_dict()
# Out:
# {'Koramangala': 2085,
#  'BTM': 669,
#  'JP Nagar': 447,
#  'Jayanagar': 443,
#  'Whitefield': 406,
#  'Electronic City': 401,
#  'HSR': 401,
#  'Bannerghatta Road': 400,
#  'Brookefield': 368,
#  'Marathahalli': 345,
#  'Indiranagar': 305,
#  'Kalyan Nagar': 303,
#  'Church Street': 302,
#  'Kammanahalli': 295,
#  'Lavelle Road': 286,
#  'Brigade Road': 285,
#  'MG Road': 279,
#  'Residency Road': 262,
#  'Bellandur': 256,
#  'Frazer Town': 228,
#  'Sarjapur Road': 222,
#  'Old Airport Road': 217,
#  'Rajajinagar': 201,
#  'Basavanagudi': 194,
#  'New BEL Road': 168,
#  'Malleshwaram': 149,
#  'Banashankari': 135}

# %% [markdown]
# ## Save the chunks

# %%
save_folder = 'gs://foundation_project2/prediction_folder'
for area in unrated_rest.area.unique():
    # filter the df
    chunk = unrated_rest[unrated_rest.area==area].drop(columns=['area'])
    filename = area.lower()+'.csv'
    filepath = '{}/{}'.format(save_folder,filename)
    chunk.to_csv(filepath, index=False)
    print('Saved to {}'.format(filepath))
# Out:
# Saved to gs://foundation_project2/prediction_folder/banashankari.csv
# Saved to gs://foundation_project2/prediction_folder/bannerghatta road.csv
# Saved to gs://foundation_project2/prediction_folder/basavanagudi.csv
# Saved to gs://foundation_project2/prediction_folder/bellandur.csv
# Saved to gs://foundation_project2/prediction_folder/brigade road.csv
# Saved to gs://foundation_project2/prediction_folder/brookefield.csv
# Saved to gs://foundation_project2/prediction_folder/btm.csv
# Saved to gs://foundation_project2/prediction_folder/church street.csv
# Saved to gs://foundation_project2/prediction_folder/electronic city.csv
# Saved to gs://foundation_project2/prediction_folder/frazer town.csv
# Saved to gs://foundation_project2/prediction_folder/hsr.csv
# Saved to gs://foundation_project2/prediction_folder/indiranagar.csv
# Saved to gs://foundation_project2/prediction_folder/jayanagar.csv
# Saved to gs://foundation_project2/prediction_folder/jp nagar.csv
# Saved to gs://foundation_project2/prediction_folder/kalyan nagar.csv
# Saved to gs://foundation_project2/prediction_folder/kammanahalli.csv
# Saved to gs://foundation_project2/prediction_folder/koramangala.csv
# Saved to gs://foundation_project2/prediction_folder/lavelle road.csv
# Saved to gs://foundation_project2/prediction_folder/malleshwaram.csv
# Saved to gs://foundation_project2/prediction_folder/marathahalli.csv
# Saved to gs://foundation_project2/prediction_folder/mg road.csv
# Saved to gs://foundation_project2/prediction_folder/new bel road.csv
# Saved to gs://foundation_project2/prediction_folder/old airport road.csv
# Saved to gs://foundation_project2/prediction_folder/rajajinagar.csv
# Saved to gs://foundation_project2/prediction_folder/residency road.csv
# Saved to gs://foundation_project2/prediction_folder/sarjapur road.csv
# Saved to gs://foundation_project2/prediction_folder/whitefield.csv
